# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("retail_sales_dataset.csv")

# %%
df.head()
# Out:
#     order_id       product     category quantity    price        date  \
# 0  ORD100000         Mouse  Accessories      two     9999         NaN
# 1  ORD100001      Keyboard          NaN        6      999         NaN
# 2  ORD100002        router          NaN       -1  unknown         NaN
# 3  ORD100003           NaN          NaN      two     1499  2024-03-14
# 4  ORD100004   Smartwatch   electronics      two      499  2023/03/04
#
#        time     city channel
# 0       NaN   Mumbai     NaN
# 1       NaN      NaN  Online
# 2       NaN  Kolkata     NaN
# 3  12:00 AM    Delhi     NaN
# 4       NaN     Pune   store

# %%
df.shape
# Out:
# (77000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77000 entries, 0 to 76999
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   order_id  77000 non-null  object
#  1   product   57836 non-null  object
#  2   category  51542 non-null  object
#  3   quantity  69212 non-null  object
#  4   price     70608 non-null  object
#  5   date      61552 non-null  object
#  6   time      57670 non-null  object
#  7   city      69925 non-null  object
#  8   channel   67468 non-null  object
# dtypes: object(9)
# memory usage: 5.3+ MB

# %%
df.isnull().sum()
# Out:
# order_id        0
# product     19164
# category    25458
# quantity     7788
# price        6392
# date        15448
# time        19330
# city         7075
# channel      9532
# dtype: int64

# %%
(df.isnull().mean() * 100).round(2)
# Out:
# order_id     0.00
# product     24.89
# category    33.06
# quantity    10.11
# price        8.30
# date        20.06
# time        25.10
# city         9.19
# channel     12.38
# dtype: float64

# %%
df.describe()
# Out:
#          order_id     product     category quantity    price        date  \
# count       77000       57836        51542    69212    70608       61552
# unique      75000          45            6        9       11        2804
# top     ORD101936  Headphones  electronics        5  unknown  2023/06/28
# freq            2        1361        13767     7814     6549          44
#
#             time     city channel
# count      57670    69925   67468
# unique         3       18       7
# top     12:00 AM  Kolkata  Online
# freq       19351     7186    9761

# %%
df.duplicated().sum()
# Out:
# np.int64(2000)

# %%
df = df.drop_duplicates()

# %%
df.dtypes
# Out:
# order_id    object
# product     object
# category    object
# quantity    object
# price       object
# date        object
# time        object
# city        object
# channel     object
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %%
df
# Out:
#         order_id       product     category quantity    price       date  \
# 0      ORD100000         Mouse  Accessories      two     9999        NaT
# 1      ORD100001      Keyboard          NaN        6      999        NaT
# 2      ORD100002        router          NaN       -1  unknown        NaT
# 3      ORD100003           NaN          NaN      two     1499 2024-03-14
# 4      ORD100004   Smartwatch   electronics      two      499        NaT
# ...          ...           ...          ...      ...      ...        ...
# 74995  ORD174995    headphones  accessories        4      NaN 2024-11-09
# 74996  ORD174996    Smartphone          NaN        5      499 2023-01-18
# 74997  ORD174997        tablet  Electronics        6      799        NaT
# 74998  ORD174998      keyboard  accessories        5     1999        NaT
# 74999  ORD174999           NaN  accessories      two     4999        NaT
#
#            time       city channel
# 0           NaN     Mumbai     NaN
# 1           NaN        NaN  Online
# 2           NaN    Kolkata     NaN
# 3      12:00 AM      Delhi     NaN
# 4           NaN       Pune   store
# ...         ...        ...     ...
# 74995       NaN        NaN   Store
# 74996     00:00      Delhi   Store
# 74997  12:00 AM     Mumbai     App
# 74998       NaN    Jaipur    Store
# 74999  00:00:00  Bangalore     WEB
#
# [75000 rows x 9 columns]

# %%
df['time'] = pd.to_datetime(df['time'], format='%I:%M %p', errors='coerce').dt.time

# %%
df['quantity'] = pd.to_numeric(df['quantity'], errors='coerce')

# %%
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# %%
df
# Out:
#         order_id       product     category  quantity   price       date  \
# 0      ORD100000         Mouse  Accessories       NaN  9999.0        NaT
# 1      ORD100001      Keyboard          NaN       6.0   999.0        NaT
# 2      ORD100002        router          NaN      -1.0     NaN        NaT
# 3      ORD100003           NaN          NaN       NaN  1499.0 2024-03-14
# 4      ORD100004   Smartwatch   electronics       NaN   499.0        NaT
# ...          ...           ...          ...       ...     ...        ...
# 74995  ORD174995    headphones  accessories       4.0     NaN 2024-11-09
# 74996  ORD174996    Smartphone          NaN       5.0   499.0 2023-01-18
# 74997  ORD174997        tablet  Electronics       6.0   799.0        NaT
# 74998  ORD174998      keyboard  accessories       5.0  1999.0        NaT
# 74999  ORD174999           NaN  accessories       NaN  4999.0        NaT
#
#            time       city channel
# 0           NaT     Mumbai     NaN
# 1           NaT        NaN  Online
# 2           NaT    Kolkata     NaN
# 3      00:00:00      Delhi     NaN
# 4           NaT       Pune   store
# ...         ...        ...     ...
# 74995       NaT        NaN   Store
# 74996       NaT      Delhi   Store
# 74997  00:00:00     Mumbai     App
# 74998       NaT    Jaipur    Store
# 74999       NaT  Bangalore     WEB
#
# [75000 rows x 9 columns]

# %%
df['category'] = df['category'].str.strip().str.title()

# %%
df['product'] = df['product'].str.strip().str.title()

# %%
df['city'] = df['city'].str.strip().str.title()

# %%
df['channel'] = df['channel'].str.strip().str.title()

# %%
df["category"].fillna("Unknown_Category", inplace=True)
# Out:
# C:\Users\akashdeep\AppData\Local\Temp\ipykernel_10048\1720458389.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["category"].fillna("Unknown_Category", inplace=True)

# %%
df["product"].fillna("Others", inplace=True)
# Out:
# C:\Users\akashdeep\AppData\Local\Temp\ipykernel_10048\2779475510.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["product"].fillna("Others", inplace=True)

# %%
df["city"].fillna(df["city"].mode()[0], inplace=True)
# Out:
# C:\Users\akashdeep\AppData\Local\Temp\ipykernel_10048\2983126315.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["city"].fillna(df["city"].mode()[0], inplace=True)

# %%
df["channel"].fillna("Unknown_channel", inplace=True)
# Out:
# C:\Users\akashdeep\AppData\Local\Temp\ipykernel_10048\542732371.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["channel"].fillna("Unknown_channel", inplace=True)

# %%
df
# Out:
#         order_id     product          category  quantity   price       date  \
# 0      ORD100000       Mouse       Accessories       NaN  9999.0        NaT
# 1      ORD100001    Keyboard  Unknown_Category       6.0   999.0        NaT
# 2      ORD100002      Router  Unknown_Category      -1.0     NaN        NaT
# 3      ORD100003      Others  Unknown_Category       NaN  1499.0 2024-03-14
# 4      ORD100004  Smartwatch       Electronics       NaN   499.0        NaT
# ...          ...         ...               ...       ...     ...        ...
# 74995  ORD174995  Headphones       Accessories       4.0     NaN 2024-11-09
# 74996  ORD174996  Smartphone  Unknown_Category       5.0   499.0 2023-01-18
# 74997  ORD174997      Tablet       Electronics       6.0   799.0        NaT
# 74998  ORD174998    Keyboard       Accessories       5.0  1999.0        NaT
# 74999  ORD174999      Others       Accessories       NaN  4999.0        NaT
#
#            time       city          channel
# 0           NaT     Mumbai  Unknown_channel
# 1           NaT    Kolkata           Online
# 2           NaT    Kolkata  Unknown_channel
# 3      00:00:00      Delhi  Unknown_channel
# 4           NaT       Pune            Store
# ...         ...        ...              ...
# 74995       NaT    Kolkata            Store
# 74996       NaT      Delhi            Store
# 74997  00:00:00     Mumbai              App
# 74998       NaT     Jaipur            Store
# 74999       NaT  Bangalore              Web
#
# [75000 rows x 9 columns]

# %%
df['quantity'].fillna(df['quantity'].median(), inplace=True)
# Out:
# C:\Users\akashdeep\AppData\Local\Temp\ipykernel_10048\1755013587.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['quantity'].fillna(df['quantity'].median(), inplace=True)

# %%
df['price'].fillna(df['price'].median(), inplace=True)
# Out:
# C:\Users\akashdeep\AppData\Local\Temp\ipykernel_10048\1576110267.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['price'].fillna(df['price'].median(), inplace=True)

# %%
df['date'].fillna(method='ffill', inplace=True)
# Out:
# C:\Users\akashdeep\AppData\Local\Temp\ipykernel_10048\470388221.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['date'].fillna(method='ffill', inplace=True)
# C:\Users\akashdeep\AppData\Local\Temp\ipykernel_10048\470388221.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['date'].fillna(method='ffill', inplace=True)

# %%
df
# Out:
#         order_id     product          category  quantity   price       date  \
# 0      ORD100000       Mouse       Accessories       3.0  9999.0        NaT
# 1      ORD100001    Keyboard  Unknown_Category       6.0   999.0        NaT
# 2      ORD100002      Router  Unknown_Category      -1.0  2999.0        NaT
# 3      ORD100003      Others  Unknown_Category       3.0  1499.0 2024-03-14
# 4      ORD100004  Smartwatch       Electronics       3.0   499.0 2024-03-14
# ...          ...         ...               ...       ...     ...        ...
# 74995  ORD174995  Headphones       Accessories       4.0  2999.0 2024-11-09
# 74996  ORD174996  Smartphone  Unknown_Category       5.0   499.0 2023-01-18
# 74997  ORD174997      Tablet       Electronics       6.0   799.0 2023-01-18
# 74998  ORD174998    Keyboard       Accessories       5.0  1999.0 2023-01-18
# 74999  ORD174999      Others       Accessories       3.0  4999.0 2023-01-18
#
#            time       city          channel
# 0           NaT     Mumbai  Unknown_channel
# 1           NaT    Kolkata           Online
# 2           NaT    Kolkata  Unknown_channel
# 3      00:00:00      Delhi  Unknown_channel
# 4           NaT       Pune            Store
# ...         ...        ...              ...
# 74995       NaT    Kolkata            Store
# 74996       NaT      Delhi            Store
# 74997  00:00:00     Mumbai              App
# 74998       NaT     Jaipur            Store
# 74999       NaT  Bangalore              Web
#
# [75000 rows x 9 columns]

# %%
df['time'].fillna(method='ffill', inplace=True)
# Out:
# C:\Users\akashdeep\AppData\Local\Temp\ipykernel_10048\596065226.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['time'].fillna(method='ffill', inplace=True)
# C:\Users\akashdeep\AppData\Local\Temp\ipykernel_10048\596065226.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['time'].fillna(method='ffill', inplace=True)

# %%
df = df[df['quantity'] > 0]
df = df[df['price'] > 0]

# %%
df['total_sales'] = df['quantity'] * df['price']

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67427 entries, 0 to 74999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     67427 non-null  object
#  1   product      67427 non-null  object
#  2   category     67427 non-null  object
#  3   quantity     67427 non-null  float64
#  4   price        67427 non-null  float64
#  5   date         67425 non-null  datetime64[ns]
#  6   time         67425 non-null  object
#  7   city         67427 non-null  object
#  8   channel      67427 non-null  object
#  9   total_sales  67427 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(6)
# memory usage: 5.7+ MB
# order_id       0
# product        0
# category       0
# quantity       0
# price          0
# date           2
# time           2
# city           0
# channel        0
# total_sales    0
# dtype: int64

# %%
df
# Out:
#         order_id     product          category  quantity   price       date  \
# 0      ORD100000       Mouse       Accessories       3.0  9999.0        NaT
# 1      ORD100001    Keyboard  Unknown_Category       6.0   999.0        NaT
# 3      ORD100003      Others  Unknown_Category       3.0  1499.0 2024-03-14
# 4      ORD100004  Smartwatch       Electronics       3.0   499.0 2024-03-14
# 5      ORD100005      Others       Accessories       2.0  2999.0 2024-03-14
# ...          ...         ...               ...       ...     ...        ...
# 74995  ORD174995  Headphones       Accessories       4.0  2999.0 2024-11-09
# 74996  ORD174996  Smartphone  Unknown_Category       5.0   499.0 2023-01-18
# 74997  ORD174997      Tablet       Electronics       6.0   799.0 2023-01-18
# 74998  ORD174998    Keyboard       Accessories       5.0  1999.0 2023-01-18
# 74999  ORD174999      Others       Accessories       3.0  4999.0 2023-01-18
#
#            time       city          channel  total_sales
# 0           NaT     Mumbai  Unknown_channel      29997.0
# 1           NaT    Kolkata           Online       5994.0
# 3      00:00:00      Delhi  Unknown_channel       4497.0
# 4      00:00:00       Pune            Store       1497.0
# 5      00:00:00    Kolkata              Web       5998.0
# ...         ...        ...              ...          ...
# 74995  00:00:00    Kolkata            Store      11996.0
# 74996  00:00:00      Delhi            Store       2495.0
# 74997  00:00:00     Mumbai              App       4794.0
# 74998  00:00:00     Jaipur            Store       9995.0
# 74999  00:00:00  Bangalore              Web      14997.0
#
# [67427 rows x 10 columns]

# %%
del df["time"]

# %%
df
# Out:
#         order_id     product          category  quantity   price       date  \
# 0      ORD100000       Mouse       Accessories       3.0  9999.0        NaT
# 1      ORD100001    Keyboard  Unknown_Category       6.0   999.0        NaT
# 3      ORD100003      Others  Unknown_Category       3.0  1499.0 2024-03-14
# 4      ORD100004  Smartwatch       Electronics       3.0   499.0 2024-03-14
# 5      ORD100005      Others       Accessories       2.0  2999.0 2024-03-14
# ...          ...         ...               ...       ...     ...        ...
# 74995  ORD174995  Headphones       Accessories       4.0  2999.0 2024-11-09
# 74996  ORD174996  Smartphone  Unknown_Category       5.0   499.0 2023-01-18
# 74997  ORD174997      Tablet       Electronics       6.0   799.0 2023-01-18
# 74998  ORD174998    Keyboard       Accessories       5.0  1999.0 2023-01-18
# 74999  ORD174999      Others       Accessories       3.0  4999.0 2023-01-18
#
#             city          channel  total_sales
# 0         Mumbai  Unknown_channel      29997.0
# 1        Kolkata           Online       5994.0
# 3          Delhi  Unknown_channel       4497.0
# 4           Pune            Store       1497.0
# 5        Kolkata              Web       5998.0
# ...          ...              ...          ...
# 74995    Kolkata            Store      11996.0
# 74996      Delhi            Store       2495.0
# 74997     Mumbai              App       4794.0
# 74998     Jaipur            Store       9995.0
# 74999  Bangalore              Web      14997.0
#
# [67427 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67427 entries, 0 to 74999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     67427 non-null  object
#  1   product      67427 non-null  object
#  2   category     67427 non-null  object
#  3   quantity     67427 non-null  float64
#  4   price        67427 non-null  float64
#  5   date         67425 non-null  datetime64[ns]
#  6   city         67427 non-null  object
#  7   channel      67427 non-null  object
#  8   total_sales  67427 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(5)
# memory usage: 5.1+ MB

# %%
df = df.dropna()

# %%
df
# Out:
#         order_id     product          category  quantity   price       date  \
# 3      ORD100003      Others  Unknown_Category       3.0  1499.0 2024-03-14
# 4      ORD100004  Smartwatch       Electronics       3.0   499.0 2024-03-14
# 5      ORD100005      Others       Accessories       2.0  2999.0 2024-03-14
# 6      ORD100006       Mouse       Accessories       1.0  4999.0 2024-03-14
# 7      ORD100007      Others       Electronics       3.0   499.0 2024-03-14
# ...          ...         ...               ...       ...     ...        ...
# 74995  ORD174995  Headphones       Accessories       4.0  2999.0 2024-11-09
# 74996  ORD174996  Smartphone  Unknown_Category       5.0   499.0 2023-01-18
# 74997  ORD174997      Tablet       Electronics       6.0   799.0 2023-01-18
# 74998  ORD174998    Keyboard       Accessories       5.0  1999.0 2023-01-18
# 74999  ORD174999      Others       Accessories       3.0  4999.0 2023-01-18
#
#             city          channel  total_sales
# 3          Delhi  Unknown_channel       4497.0
# 4           Pune            Store       1497.0
# 5        Kolkata              Web       5998.0
# 6      Bangalore  Unknown_channel       4999.0
# 7        Kolkata           Online       1497.0
# ...          ...              ...          ...
# 74995    Kolkata            Store      11996.0
# 74996      Delhi            Store       2495.0
# 74997     Mumbai              App       4794.0
# 74998     Jaipur            Store       9995.0
# 74999  Bangalore              Web      14997.0
#
# [67425 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67425 entries, 3 to 74999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     67425 non-null  object
#  1   product      67425 non-null  object
#  2   category     67425 non-null  object
#  3   quantity     67425 non-null  float64
#  4   price        67425 non-null  float64
#  5   date         67425 non-null  datetime64[ns]
#  6   city         67425 non-null  object
#  7   channel      67425 non-null  object
#  8   total_sales  67425 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(5)
# memory usage: 5.1+ MB

# %%
df.to_csv("cleaned_retail_sales_dataset.csv", index=False)
